# %% [markdown]
# <a href="https://colab.research.google.com/github/ZoliN/colab/blob/main/hdrnetTFv2work2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# %cd /content
# !pip3 install virtualenv
# !virtualenv env
# !git clone https://github.com/ZoliN/hdrnet
# %cd /content/hdrnet/hdrnet
# !git checkout tfv2
# !source /content/env/bin/activate;pip install -r requirements.txt
# !pip install python_magic
# !source /content/env/bin/activate; pip install matplotlib ipykernel
# !apt-get install libmagic1
# !apt-get install clang-10 -y -qq;
# !ln -sf /usr/bin/clang-10 /usr/local/cuda/bin/gcc;
# !ln -sf /usr/bin/clang-10 /usr/local/cuda/bin/g++;
import os
import sys
os.environ['CUDA_HOME'] = '/usr/local/cuda'
os.environ['PATH'] += ':/content/hdrnet'
os.environ['LD_LIBRARY_PATH'] += ':/content/env/lib/python3.8/site-packages/tensorflow'
# !echo $CUDA_HOME
# !echo $PATH
# !ln -sf /content/env/lib/python3.8/site-packages/tensorflow/include/tensorflow/ /content/hdrnet/hdrnet/ops/third_party/
# !mkdir -p /content/hdrnet/hdrnet/ops_oldslice/third_party
# !ln -sf /content/env/lib/python3.8/site-packages/tensorflow/include/tensorflow/ /content/hdrnet/hdrnet/ops_oldslice/third_party/
# !mkdir -p /content/env/lib/python3.8/site-packages/tensorflow/include/third_party/gpus/cuda
# !ln -sf /usr/local/cuda/include  /content/env/lib/python3.8/site-packages/tensorflow/include/third_party/gpus/cuda

# !cp /content/hdrnet/hdrnet/fixes/gpu_device_functions.h /content/env/lib/python3.8/site-packages/tensorflow/include/tensorflow/core/util/gpu_device_functions.h
# !cp /content/hdrnet/hdrnet/fixes/compressed_tuple.h /content/env/lib/python3.8/site-packages/tensorflow/include/absl/container/internal/compressed_tuple.h
# !cp /content/hdrnet/hdrnet/fixes/config.h /content/env/lib/python3.8/site-packages/tensorflow/include/absl/base/config.h

# !mkdir -p /content/hdrnet/train/data/input
# !mkdir -p /content/hdrnet/train/data/output
# !mkdir -p /content/hdrnet/train/data/out
# !mkdir -p /content/hdrnet/train/test
# !unzip -o /content/gdrive/MyDrive/hdrnet/t1.zip -d /content/hdrnet/train/data/
# Out:
# /content
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting virtualenv
#   Downloading virtualenv-20.17.1-py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 55.9 MB/s eta 0:00:00
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 KB 45.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock<4,>=3.4.1 in /usr/local/lib/python3.8/dist-packages (from virtualenv) (3.9.0)
# Requirement already satisfied: platformdirs<3,>=2.4 in /usr/local/lib/python3.8/dist-packages (from virtualenv) (2.6.2)
# Installing collected packages: distlib, virtualenv
# Successfully installed distlib-0.3.6 virtualenv-20.17.1
# created virtual environment CPython3.8.16.final.0-64 in 766ms
#   creator CPython3Posix(dest=/content/env, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==22.3.1, setuptools==65.6.3, wheel==0.38.4
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator
# Cloning into 'hdrnet'...
# remote: Enumerating objects: 351, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 351 (delta 48), reused 82 (delta 33), pack-reused 243
# Receiving objects: 100% (351/351), 9.57 MiB | 30.14 MiB/s, done.
# Resolving deltas: 100% (184/184), done.
# /content/hdrnet/hdrnet
# Branch 'tfv2' set up to track remote branch 'tfv2' from 'origin'.
# Switched to a new branch 'tfv2'
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting numpy
#   Downloading numpy-1.24.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 76.7 MB/s eta 0:00:00
# Collecting pyglib
#   Downloading pyglib-0.1.tar.gz (4.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting scikit_image
#   Downloading scikit_image-0.19.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 83.7 MB/s eta 0:00:00
# Collecting python_gflags
#   Downloading python-gflags-3.1.2.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.1/52.1 kB 8.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting python_magic
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Collecting tensorflow-gpu==2.9.3
#   Downloading tensorflow_gpu-2.9.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (511.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 511.8/511.8 MB 3.2 MB/s eta 0:00:00
# Collecting tensorflow-probability==0.17.0
#   Downloading tensorflow_probability-0.17.0-py2.py3-none-any.whl (6.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.5/6.5 MB 97.9 MB/s eta 0:00:00
# Collecting opencv-python
#   Downloading opencv_python-4.7.0.68-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 13.0 MB/s eta 0:00:00
# Collecting pytest
#   Downloading pytest-7.2.0-py3-none-any.whl (316 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.8/316.8 kB 38.1 MB/s eta 0:00:00
# Collecting keras-preprocessing>=1.1.1
#   Downloading Keras_Preprocessing-1.1.2-py2.py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /content/env/lib/python3.8/site-packages (from tensorflow-gpu==2.9.3->-r requirements.txt (line 7)) (65.6.3)
# Collecting packaging
#   Downloading packaging-23.0-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 6.4 MB/s eta 0:00:00
# Collecting tensorflow-estimator<2.10.0,>=2.9.0rc0
#   Downloading tensorflow_estimator-2.9.0-py2.py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.7/438.7 kB 45.4 MB/s eta 0:00:00
# Collecting typing-extensions>=3.6.6
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Collecting six>=1.12.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting tensorboard<2.10,>=2.9
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 101.3 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.51.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 88.6 MB/s eta 0:00:00
# Collecting termcolor>=1.1.0
#   Downloading termcolor-2.2.0-py3-none-any.whl (6.6 kB)
# Collecting astunparse>=1.6.0
#   Downloading astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.1 MB/s eta 0:00:00
# Collecting absl-py>=1.0.0
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 15.7 MB/s eta 0:00:00
# Collecting opt-einsum>=2.3.2
#   Downloading opt_einsum-3.3.0-py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 9.3 MB/s eta 0:00:00
# Collecting flatbuffers<2,>=1.12
#   Downloading flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting keras<2.10.0,>=2.9.0rc0
#   Downloading keras-2.9.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 64.8 MB/s eta 0:00:00
# Collecting h5py>=2.9.0
#   Downloading h5py-3.7.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 96.9 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.1
#   Downloading google_pasta-0.2.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 8.4 MB/s eta 0:00:00
# Collecting wrapt>=1.11.0
#   Downloading wrapt-1.14.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 11.8 MB/s eta 0:00:00
# Collecting gast<=0.4.0,>=0.2.1
#   Downloading gast-0.4.0-py3-none-any.whl (9.8 kB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.29.0-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 76.5 MB/s eta 0:00:00
# Collecting libclang>=13.0.0
#   Downloading libclang-15.0.6.1-py2.py3-none-manylinux2010_x86_64.whl (21.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.5/21.5 MB 78.5 MB/s eta 0:00:00
# Collecting dm-tree
#   Downloading dm_tree-0.1.8-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.9/152.9 kB 23.0 MB/s eta 0:00:00
# Collecting cloudpickle>=1.3
#   Downloading cloudpickle-2.2.0-py3-none-any.whl (25 kB)
# Collecting decorator
#   Downloading decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting glog
#   Downloading glog-0.3.1-py2.py3-none-any.whl (7.8 kB)
# Collecting pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0
#   Downloading Pillow-9.4.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 75.3 MB/s eta 0:00:00
# Collecting imageio>=2.4.1
#   Downloading imageio-2.24.0-py3-none-any.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 78.8 MB/s eta 0:00:00
# Collecting tifffile>=2019.7.26
#   Downloading tifffile-2022.10.10-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.3/210.3 kB 29.2 MB/s eta 0:00:00
# Collecting PyWavelets>=1.1.1
#   Downloading PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 89.8 MB/s eta 0:00:00
# Collecting scipy>=1.4.1
#   Downloading scipy-1.10.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.5/34.5 MB 14.7 MB/s eta 0:00:00
# Collecting networkx>=2.2
#   Downloading networkx-3.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 73.8 MB/s eta 0:00:00
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.1.0-py3-none-any.whl (14 kB)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting attrs>=19.2.0
#   Downloading attrs-22.2.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 8.6 MB/s eta 0:00:00
# Collecting tomli>=1.0.0
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /content/env/lib/python3.8/site-packages (from astunparse>=1.6.0->tensorflow-gpu==2.9.3->-r requirements.txt (line 7)) (0.38.4)
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.2-py3-none-any.whl (232 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.7/232.7 kB 15.6 MB/s eta 0:00:00
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.16.0-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.8/177.8 kB 22.4 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 17.5 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 48.8 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting requests<3,>=2.21.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 9.1 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 12.1 MB/s eta 0:00:00
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 18.7 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.1-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting importlib-metadata>=4.4
#   Downloading importlib_metadata-6.0.0-py3-none-any.whl (21 kB)
# Collecting idna<4,>=2.5
#   Downloading idna-3.4-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 7.6 MB/s eta 0:00:00
# Collecting charset-normalizer<3,>=2
#   Downloading charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.14-py2.py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 9.7 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 19.1 MB/s eta 0:00:00
# Collecting MarkupSafe>=2.1.1
#   Downloading MarkupSafe-2.1.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.11.0-py3-none-any.whl (6.6 kB)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 12.4 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 24.1 MB/s eta 0:00:00
# Building wheels for collected packages: pyglib, python_gflags
#   Building wheel for pyglib (setup.py) ... done
#   Created wheel for pyglib: filename=pyglib-0.1-py2.py3-none-any.whl size=4527 sha256=d971bac78b57e0126a34e728919e0f488a9c081c3e04f76271e2555386c93c24
#   Stored in directory: /root/.cache/pip/wheels/5a/76/a5/7257caf2b3767e50006ac328ff37dcf87f822650ef3a6592ca
#   Building wheel for python_gflags (setup.py) ... done
#   Created wheel for python_gflags: filename=python_gflags-3.1.2-py3-none-any.whl size=57371 sha256=74d09a15f318503d5f302af0a491afc3feacbd9412e9c7b18583830b2666e525
#   Stored in directory: /root/.cache/pip/wheels/58/ba/05/e10e14191ae198718f36cb0d499432168b3018abd3e133f271
# Successfully built pyglib python_gflags
# Installing collected packages: tensorboard-plugin-wit, python_gflags, pyasn1, libclang, keras, flatbuffers, dm-tree, zipp, wrapt, urllib3, typing-extensions, tomli, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, six, setproctitle, rsa, python_magic, pyasn1-modules, protobuf, pluggy, pillow, packaging, oauthlib, numpy, networkx, MarkupSafe, iniconfig, idna, grpcio, gast, exceptiongroup, decorator, cloudpickle, charset-normalizer, certifi, cachetools, attrs, absl-py, werkzeug, tifffile, tensorflow-probability, scipy, requests, PyWavelets, pytest, opt-einsum, opencv-python, keras-preprocessing, importlib-metadata, imageio, h5py, google-pasta, google-auth, glog, astunparse, scikit_image, requests-oauthlib, pyglib, markdown, google-auth-oauthlib, tensorboard, tensorflow-gpu
# Successfully installed MarkupSafe-2.1.1 PyWavelets-1.4.1 absl-py-1.4.0 astunparse-1.6.3 attrs-22.2.0 cachetools-5.2.1 certifi-2022.12.7 charset-normalizer-2.1.1 cloudpickle-2.2.0 decorator-5.1.1 dm-tree-0.1.8 exceptiongroup-1.1.0 flatbuffers-1.12 gast-0.4.0 glog-0.3.1 google-auth-2.16.0 google-auth-oauthlib-0.4.6 google-pasta-0.2.0 grpcio-1.51.1 h5py-3.7.0 idna-3.4 imageio-2.24.0 importlib-metadata-6.0.0 iniconfig-2.0.0 keras-2.9.0 keras-preprocessing-1.1.2 libclang-15.0.6.1 markdown-3.4.1 networkx-3.0 numpy-1.24.1 oauthlib-3.2.2 opencv-python-4.7.0.68 opt-einsum-3.3.0 packaging-23.0 pillow-9.4.0 pluggy-1.0.0 protobuf-3.19.6 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyglib-0.1 pytest-7.2.0 python_gflags-3.1.2 python_magic-0.4.27 requests-2.28.1 requests-oauthlib-1.3.1 rsa-4.9 scikit_image-0.19.3 scipy-1.10.0 setproctitle-1.3.2 six-1.16.0 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 tensorflow-estimator-2.9.0 tensorflow-gpu-2.9.3 tensorflow-io-gcs-filesystem-0.29.0 tensorflow-probability-0.17.0 termcolor-2.2.0 tifffile-2022.10.10 tomli-2.0.1 typing-extensions-4.4.0 urllib3-1.26.14 werkzeug-2.2.2 wrapt-1.14.1 zipp-3.11.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting python_magic
#   Using cached python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Installing collected packages: python_magic
# Successfully installed python_magic-0.4.27
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libmagic-mgc
# Suggested packages:
#   file
# The following NEW packages will be installed:
#   libmagic-mgc libmagic1
# 0 upgraded, 2 newly installed, 0 to remove and 21 not upgraded.
# Need to get 252 kB of archives.
# After this operation, 5,214 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Fetched 252 kB in 1s (303 kB/s)
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 124016 files and directories currently installed.)
# Preparing to unpack .../libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# Selecting previously unselected package python3-yaml.
# (Reading database ... 124038 files and directories currently installed.)
# Preparing to unpack .../00-python3-yaml_3.12-1build2_amd64.deb ...
# Unpacking python3-yaml (3.12-1build2) ...
# Selecting previously unselected package binfmt-support.
# Preparing to unpack .../01-binfmt-support_2.1.8-2_amd64.deb ...
# Unpacking binfmt-support (2.1.8-2) ...
# Selecting previously unselected package libclang-cpp10.
# Preparing to unpack .../02-libclang-cpp10_1%3a10.0.0-4ubuntu1~18.04.2_amd64.deb ...
# Unpacking libclang-cpp10 (1:10.0.0-4ubuntu1~18.04.2) ...
# Selecting previously unselected package libclang-common-10-dev.
# Preparing to unpack .../03-libclang-common-10-dev_1%3a10.0.0-4ubuntu1~18.04.2_amd64.deb ...
# Unpacking libclang-common-10-dev (1:10.0.0-4ubuntu1~18.04.2) ...
# Selecting previously unselected package libclang1-10.
# Preparing to unpack .../04-libclang1-10_1%3a10.0.0-4ubuntu1~18.04.2_amd64.deb ...
# Unpacking libclang1-10 (1:10.0.0-4ubuntu1~18.04.2) ...
# Selecting previously unselected package clang-10.
# Preparing to unpack .../05-clang-10_1%3a10.0.0-4ubuntu1~18.04.2_amd64.deb ...
# Unpacking clang-10 (1:10.0.0-4ubuntu1~18.04.2) ...
# Selecting previously unselected package libomp5-10:amd64.
# Preparing to unpack .../06-libomp5-10_1%3a10.0.0-4ubuntu1~18.04.2_amd64.deb ...
# Unpacking libomp5-10:amd64 (1:10.0.0-4ubuntu1~18.04.2) ...
# Selecting previously unselected package libomp-10-dev.
# Preparing to unpack .../07-libomp-10-dev_1%3a10.0.0-4ubuntu1~18.04.2_amd64.deb ...
# Unpacking libomp-10-dev (1:10.0.0-4ubuntu1~18.04.2) ...
# Selecting previously unselected package llvm-10-runtime.
# Preparing to unpack .../08-llvm-10-runtime_1%3a10.0.0-4ubuntu1~18.04.2_amd64.deb ...
# Unpacking llvm-10-runtime (1:10.0.0-4ubuntu1~18.04.2) ...
# Selecting previously unselected package libpfm4:amd64.
# Preparing to unpack .../09-libpfm4_4.9.0-2_amd64.deb ...
# Unpacking libpfm4:amd64 (4.9.0-2) ...
# Selecting previously unselected package llvm-10.
# Preparing to unpack .../10-llvm-10_1%3a10.0.0-4ubuntu1~18.04.2_amd64.deb ...
# Unpacking llvm-10 (1:10.0.0-4ubuntu1~18.04.2) ...
# Selecting previously unselected package libffi-dev:amd64.
# Preparing to unpack .../11-libffi-dev_3.2.1-8_amd64.deb ...
# Unpacking libffi-dev:amd64 (3.2.1-8) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../12-python3-pygments_2.2.0+dfsg-1ubuntu0.2_all.deb ...
# Unpacking python3-pygments (2.2.0+dfsg-1ubuntu0.2) ...
# Selecting previously unselected package llvm-10-tools.
# Preparing to unpack .../13-llvm-10-tools_1%3a10.0.0-4ubuntu1~18.04.2_amd64.deb ...
# Unpacking llvm-10-tools (1:10.0.0-4ubuntu1~18.04.2) ...
# Selecting previously unselected package libz3-4:amd64.
# Preparing to unpack .../14-libz3-4_4.4.1-0.3build4_amd64.deb ...
# Unpacking libz3-4:amd64 (4.4.1-0.3build4) ...
# Selecting previously unselected package libz3-dev:amd64.
# Preparing to unpack .../15-libz3-dev_4.4.1-0.3build4_amd64.deb ...
# Unpacking libz3-dev:amd64 (4.4.1-0.3build4) ...
# Selecting previously unselected package llvm-10-dev.
# Preparing to unpack .../16-llvm-10-dev_1%3a10.0.0-4ubuntu1~18.04.2_amd64.deb ...
# Unpacking llvm-10-dev (1:10.0.0-4ubuntu1~18.04.2) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../17-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Setting up python3-yaml (3.12-1build2) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up binfmt-support (2.1.8-2) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/binfmt-support.service → /lib/systemd/system/binfmt-support.service.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libffi-dev:amd64 (3.2.1-8) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up libpfm4:amd64 (4.9.0-2) ...
# Setting up libclang-common-10-dev (1:10.0.0-4ubuntu1~18.04.2) ...
# Setting up libclang1-10 (1:10.0.0-4ubuntu1~18.04.2) ...
# Setting up libclang-cpp10 (1:10.0.0-4ubuntu1~18.04.2) ...
# Setting up llvm-10-runtime (1:10.0.0-4ubuntu1~18.04.2) ...
# Setting up libomp5-10:amd64 (1:10.0.0-4ubuntu1~18.04.2) ...
# Setting up libz3-4:amd64 (4.4.1-0.3build4) ...
# Setting up python3-pygments (2.2.0+dfsg-1ubuntu0.2) ...
# /usr/lib/python3.8/subprocess.py:842: RuntimeWarning: line buffering (buffering=1) isn't supported in binary mode, the default buffer size will be used
#   self.stdin = io.open(p2cwrite, 'wb', bufsize)
# Setting up clang-10 (1:10.0.0-4ubuntu1~18.04.2) ...
# Setting up libomp-10-dev (1:10.0.0-4ubuntu1~18.04.2) ...
# Setting up llvm-10 (1:10.0.0-4ubuntu1~18.04.2) ...
# Setting up llvm-10-tools (1:10.0.0-4ubuntu1~18.04.2) ...
# Setting up libz3-dev:amd64 (4.4.1-0.3build4) ...
# Setting up llvm-10-dev (1:10.0.0-4ubuntu1~18.04.2) ...
# Processing triggers for systemd (237-3ubuntu10.56) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.6) ...
# /usr/local/cuda
# /opt/bin:/usr/local/nvidia/bin:/usr/local/cuda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/tools/node/bin:/tools/google-cloud-sdk/bin:/content/hdrnet
# Archive:  /content/gdrive/MyDrive/hdrnet/t1.zip
#    creating: /content/hdrnet/train/data/exif/
#   inflating: /content/hdrnet/train/data/exif/BURST20201129152954573.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201129153004402.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130011414333.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130112821380.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130121525745.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130121640253.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130121657001.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130121802713.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130121858855.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130121948723.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130132502331.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130142039345.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130142107993.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130142125261.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130142137673.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130164752838.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130194208638.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201130201449803.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201202090019626.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201202113552415.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201202121621322.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201202121636074.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201205110926910.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201205111314333.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201206111910305.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201206111937761.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201206120028851.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201206123108141.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201206163155423.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201210020128581.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201210141257070.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201210141346007.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201210141438277.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201212101144443.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201213120455672.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201213121239080.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201213122520172.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201213185333968.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201214074659720.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201214074743276.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201214122005521.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201214122353157.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201214131524115.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201214132159219.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201220131401405.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201223124255049.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201223140005941.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201223142439162.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201226151910947.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201226152420677.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201227094131058.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201227102417863.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201227135159662.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201227135603468.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201227180231311.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20201231171317154.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210102144230587.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210102144717160.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210102153721699.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210102160319476.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210102161550280.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210313140454497.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210313141718089.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210313142146718.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210605164919769.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210605164941596.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210605165042010.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210605165048016.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210612132227063.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210612140313123.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210612153328845.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210701113741969.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210701134504940.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210701201346003.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210702113214730.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210702184145791.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210702194327466.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210705104546672.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210705104937314.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210705105735466.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210705105933607.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210705112119008.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210705192946545.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210706085601300.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710024208890.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710102854662.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710103107226.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710111102630.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710140100065.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710162353288.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710164014017.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710174928551.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710180140727.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710180346206.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710180501774.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210710185852048.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210711152557730.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210711182157220.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210712132348587.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210715090055723.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210716105730909.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210716105809450.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210725155548020.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210726194710873.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210727184954209.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210727194211167.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210728193439586.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210728193454669.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210728201315427.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210728201326455.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210728202258332.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210730144225997.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210801131738641.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210804093950027.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210804101725248.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210804140653717.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210805002219677.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210807140826905.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210807181914621.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210807191513235.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210807194753984.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210807194802489.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210807194812790.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210807195442582.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210814105649008.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210814144602434.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210814145002033.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210814192307222.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210815103033768.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210815135820040.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210815152915430.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210815153815747.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210815182400502.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210815200951266.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210818131630006.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210818134656363.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210818152500332.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210818153010763.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210818153135887.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210818153409378.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210818171559027.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210818180953216.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210819175806473.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210819180249659.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210820094004265.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210820095415595.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210820122934485.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210820123729684.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210820124311138.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210820145205883.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210820152814985.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210820165643906.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210820180858242.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210820191453259.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821091752418.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821091939999.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821092919012.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821093017708.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821093252055.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821101056815.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821140415160.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821141224318.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821141338659.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821141501003.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821141734386.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821142627234.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821143816238.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821152000287.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821152209808.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821194406171.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210821194452937.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090403251.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090407521.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090413258.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090552054.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090602921.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090612175.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090619444.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090708658.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090712815.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090803225.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090814770.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090831720.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090844024.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822090849903.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822092922681.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822092928026.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822092943985.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822101324026.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822101340282.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822101349493.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822101409412.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822101439584.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822102128138.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822102317403.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822102330049.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822103048926.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822103100530.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822103304757.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822103318723.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822155819518.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822165108332.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822171954492.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822172306894.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822174402814.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822174437350.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822175206594.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822175244406.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822175446505.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822175624744.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822175951867.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822180959775.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822181212717.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210822190124650.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210824115555586.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210824115629505.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210824142014547.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210824195011044.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210824195024282.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210824195037485.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210824195049089.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210824230524179.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210825194601438.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210825195426710.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210826201404969.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210827091804502.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210827091920550.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210827165315965.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210827165516313.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210827165703955.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210827185902498.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210827190836487.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210827191109534.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210828120521408.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210828131155912.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210828152526308.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210828170000148.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210828174914211.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829122811242.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829125432556.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829125439713.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829130453282.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829133034986.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829133155774.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829140826723.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829142403511.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829143103098.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829143112290.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829150912506.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210829165749521.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210902085748983.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210902085933969.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210902194629195.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904165928350.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904172217522.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904183412429.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904183420977.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904183819391.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904184052453.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904184314778.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904184838278.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904190049000.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904191208935.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904193451698.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904195232351.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210904195242012.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210905174655722.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210905175936369.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210905182451176.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210905182521273.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210905184301594.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210906185557950.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210906185608016.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210906185710452.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210906190903948.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210906190928997.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210907191647784.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210907191659715.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210909192159906.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210913185749513.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210913192136397.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210919170707837.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210919171541572.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210919172139506.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20210925154431978.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211016140151707.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211016140208811.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211016140525794.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211016141120870.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211016144628862.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211016190122005.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211017174315058.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211022110905296.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211023175502525.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211024125933939.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211024130259522.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211024134433413.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211026182306198.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211030165913298.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211030170031312.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211031091128017.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211031150455576.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211031164635010.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211031164812821.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211101144036165.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211101161409256.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211106141626462.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211107141411227.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211107142626391.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211114001728920.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211114092201242.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211114092234959.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211114092408216.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211114135841008.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120141514478.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120150904995.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120153439211.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120154532486.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120154915653.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120155249849.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120155256085.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120155304883.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120155850246.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120155901609.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120155928540.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120160310019.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120160832034.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120161158181.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120161205766.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120161602054.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120161613453.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120161732224.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120161940538.png.txt
#   inflating: /content/hdrnet/train/data/exif/BURST20211120162203050.png.txt
# ...
#   inflating: /content/hdrnet/train/data/output/BURST20210829133155774.png
#   inflating: /content/hdrnet/train/data/output/BURST20210829140826723.png
#   inflating: /content/hdrnet/train/data/output/BURST20210829142403511.png
#   inflating: /content/hdrnet/train/data/output/BURST20210829143103098.png
#   inflating: /content/hdrnet/train/data/output/BURST20210829143112290.png
#   inflating: /content/hdrnet/train/data/output/BURST20210829150912506.png
#   inflating: /content/hdrnet/train/data/output/BURST20210829165749521.png
#   inflating: /content/hdrnet/train/data/output/BURST20210902085748983.png
#   inflating: /content/hdrnet/train/data/output/BURST20210902085933969.png
#   inflating: /content/hdrnet/train/data/output/BURST20210902194629195.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904165928350.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904172217522.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904183412429.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904183420977.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904183819391.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904184052453.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904184314778.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904184838278.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904190049000.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904191208935.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904193451698.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904195232351.png
#   inflating: /content/hdrnet/train/data/output/BURST20210904195242012.png
#   inflating: /content/hdrnet/train/data/output/BURST20210905174655722.png
#   inflating: /content/hdrnet/train/data/output/BURST20210905175936369.png
#   inflating: /content/hdrnet/train/data/output/BURST20210905182451176.png
#   inflating: /content/hdrnet/train/data/output/BURST20210905182521273.png
#   inflating: /content/hdrnet/train/data/output/BURST20210905184301594.png
#   inflating: /content/hdrnet/train/data/output/BURST20210906185557950.png
#   inflating: /content/hdrnet/train/data/output/BURST20210906185608016.png
#   inflating: /content/hdrnet/train/data/output/BURST20210906185710452.png
#   inflating: /content/hdrnet/train/data/output/BURST20210906190903948.png
#   inflating: /content/hdrnet/train/data/output/BURST20210906190928997.png
#   inflating: /content/hdrnet/train/data/output/BURST20210907191647784.png
#   inflating: /content/hdrnet/train/data/output/BURST20210907191659715.png
#   inflating: /content/hdrnet/train/data/output/BURST20210909192159906.png
#   inflating: /content/hdrnet/train/data/output/BURST20210913185749513.png
#   inflating: /content/hdrnet/train/data/output/BURST20210913192136397.png
#   inflating: /content/hdrnet/train/data/output/BURST20210919170707837.png
#   inflating: /content/hdrnet/train/data/output/BURST20210919171541572.png
#   inflating: /content/hdrnet/train/data/output/BURST20210919172139506.png
#   inflating: /content/hdrnet/train/data/output/BURST20210925154431978.png
#   inflating: /content/hdrnet/train/data/output/BURST20211016140151707.png
#   inflating: /content/hdrnet/train/data/output/BURST20211016140208811.png
#   inflating: /content/hdrnet/train/data/output/BURST20211016140525794.png
#   inflating: /content/hdrnet/train/data/output/BURST20211016141120870.png
#   inflating: /content/hdrnet/train/data/output/BURST20211016144628862.png
#   inflating: /content/hdrnet/train/data/output/BURST20211016190122005.png
#   inflating: /content/hdrnet/train/data/output/BURST20211017174315058.png
#   inflating: /content/hdrnet/train/data/output/BURST20211022110905296.png
#   inflating: /content/hdrnet/train/data/output/BURST20211023175502525.png
#   inflating: /content/hdrnet/train/data/output/BURST20211024125933939.png
#   inflating: /content/hdrnet/train/data/output/BURST20211024130259522.png
#   inflating: /content/hdrnet/train/data/output/BURST20211024134433413.png
#   inflating: /content/hdrnet/train/data/output/BURST20211026182306198.png
#   inflating: /content/hdrnet/train/data/output/BURST20211030165913298.png
#   inflating: /content/hdrnet/train/data/output/BURST20211030170031312.png
#   inflating: /content/hdrnet/train/data/output/BURST20211031091128017.png
#   inflating: /content/hdrnet/train/data/output/BURST20211031150455576.png
#   inflating: /content/hdrnet/train/data/output/BURST20211031164635010.png
#   inflating: /content/hdrnet/train/data/output/BURST20211031164812821.png
#   inflating: /content/hdrnet/train/data/output/BURST20211101144036165.png
#   inflating: /content/hdrnet/train/data/output/BURST20211101161409256.png
#   inflating: /content/hdrnet/train/data/output/BURST20211106141626462.png
#   inflating: /content/hdrnet/train/data/output/BURST20211107141411227.png
#   inflating: /content/hdrnet/train/data/output/BURST20211107142626391.png
#   inflating: /content/hdrnet/train/data/output/BURST20211114001728920.png
#   inflating: /content/hdrnet/train/data/output/BURST20211114092201242.png
#   inflating: /content/hdrnet/train/data/output/BURST20211114092234959.png
#   inflating: /content/hdrnet/train/data/output/BURST20211114092408216.png
#   inflating: /content/hdrnet/train/data/output/BURST20211114135841008.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120141514478.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120150904995.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120153439211.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120154532486.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120154915653.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120155249849.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120155256085.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120155304883.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120155850246.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120155901609.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120155928540.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120160310019.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120160832034.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120161158181.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120161205766.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120161602054.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120161613453.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120161732224.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120161940538.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120162203050.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120162414637.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120162422828.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120162432667.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120162443366.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120162453889.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120163458994.png
#   inflating: /content/hdrnet/train/data/output/BURST20211120171319802.png
#   inflating: /content/hdrnet/train/data/output/BURST20211123010300382.png
#   inflating: /content/hdrnet/train/data/output/BURST20211123011626475.png
#   inflating: /content/hdrnet/train/data/output/BURST20211123011659590.png
#   inflating: /content/hdrnet/train/data/output/BURST20211123011719904.png
#   inflating: /content/hdrnet/train/data/output/BURST20211128204321959.png
#   inflating: /content/hdrnet/train/data/output/BURST20211130154417850.png
#   inflating: /content/hdrnet/train/data/output/BURST20211130154536805.png
#   inflating: /content/hdrnet/train/data/output/BURST20211130154546579.png
#   inflating: /content/hdrnet/train/data/output/BURST20211130154551998.png
#   inflating: /content/hdrnet/train/data/output/BURST20211130154557253.png
#   inflating: /content/hdrnet/train/data/output/BURST20211130154743789.png
#   inflating: /content/hdrnet/train/data/output/BURST20211130154756708.png
#   inflating: /content/hdrnet/train/data/output/BURST20211130155238469.png
#   inflating: /content/hdrnet/train/data/output/BURST20211130155252015.png
#   inflating: /content/hdrnet/train/data/output/BURST20211201020502590.png
#   inflating: /content/hdrnet/train/data/output/BURST20211201020509605.png
#   inflating: /content/hdrnet/train/data/output/BURST20211201020520005.png
#   inflating: /content/hdrnet/train/data/output/BURST20211201020530997.png
#   inflating: /content/hdrnet/train/data/output/BURST20211201020542790.png
#   inflating: /content/hdrnet/train/data/output/BURST20211201020639762.png
#   inflating: /content/hdrnet/train/data/output/BURST20211201020653117.png
#   inflating: /content/hdrnet/train/data/output/BURST20211201020705573.png
#   inflating: /content/hdrnet/train/data/output/BURST20211201020713274.png
#   inflating: /content/hdrnet/train/data/output/BURST20211202133320571.png
#   inflating: /content/hdrnet/train/data/output/BURST20211202133352689.png
#   inflating: /content/hdrnet/train/data/output/BURST20211202133407718.png
#   inflating: /content/hdrnet/train/data/output/BURST20211202133417536.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204122505763.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204131145328.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204132156349.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204132524338.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204141048254.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204141213865.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204150223328.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204150603519.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204150735794.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204152418575.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204153141868.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204153157917.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204153203351.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204153257348.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204153535980.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204182508198.png
#   inflating: /content/hdrnet/train/data/output/BURST20211204182638445.png
#   inflating: /content/hdrnet/train/data/output/BURST20211205101612776.png
#   inflating: /content/hdrnet/train/data/output/BURST20211205101621697.png
#   inflating: /content/hdrnet/train/data/output/BURST20211205101720532.png
#   inflating: /content/hdrnet/train/data/output/BURST20211205101757588.png
#   inflating: /content/hdrnet/train/data/output/BURST20211205101806530.png
#   inflating: /content/hdrnet/train/data/output/BURST20211205101819051.png
#   inflating: /content/hdrnet/train/data/output/BURST20211205101825430.png
#   inflating: /content/hdrnet/train/data/output/BURST20211205102128011.png
#   inflating: /content/hdrnet/train/data/output/BURST20211205102133878.png
#   inflating: /content/hdrnet/train/data/output/BURST20211205102143324.png
#   inflating: /content/hdrnet/train/data/output/BURST20211219121057931.png
#   inflating: /content/hdrnet/train/data/output/BURST20211219121106864.png
#   inflating: /content/hdrnet/train/data/output/BURST20211219125937479.png
#   inflating: /content/hdrnet/train/data/output/BURST20211231162854517.png
#   inflating: /content/hdrnet/train/data/output/BURST20211231162910345.png
#   inflating: /content/hdrnet/train/data/output/BURST20220211161308806.png
#   inflating: /content/hdrnet/train/data/output/BURST20220211162608444.png
#   inflating: /content/hdrnet/train/data/output/BURST20220217100749074.png
#   inflating: /content/hdrnet/train/data/output/BURST20220306154828917.png
#   inflating: /content/hdrnet/train/data/output/BURST20220313150156735.png
#   inflating: /content/hdrnet/train/data/output/BURST20220313153324548.png
#   inflating: /content/hdrnet/train/data/output/BURST20220313161111871.png
#   inflating: /content/hdrnet/train/data/output/BURST20220313161119357.png
#   inflating: /content/hdrnet/train/data/output/BURST20220313161123567.png
#   inflating: /content/hdrnet/train/data/output/BURST20220313161127772.png
#   inflating: /content/hdrnet/train/data/output/BURST20220314114101209.png
#   inflating: /content/hdrnet/train/data/output/BURST20220319130935977.png
#   inflating: /content/hdrnet/train/data/output/BURST20220320122840218.png
#   inflating: /content/hdrnet/train/data/output/BURST20220320123234657.png
#   inflating: /content/hdrnet/train/data/output/BURST20220320123254797.png
#   inflating: /content/hdrnet/train/data/output/BURST20220326160355149.png
#   inflating: /content/hdrnet/train/data/output/BURST20220326160529856.png
#   inflating: /content/hdrnet/train/data/output/BURST20220326160557959.png
#   inflating: /content/hdrnet/train/data/output/BURST20220402131516382.png
#   inflating: /content/hdrnet/train/data/output/BURST20220402133620503.png
#   inflating: /content/hdrnet/train/data/output/BURST20220403154828918.png
#   inflating: /content/hdrnet/train/data/output/BURST20220406092813465.png
#   inflating: /content/hdrnet/train/data/output/BURST20220417094934489.png
#   inflating: /content/hdrnet/train/data/output/BURST20220417100326083.png
#   inflating: /content/hdrnet/train/data/output/BURST20220417181715700.png
#   inflating: /content/hdrnet/train/data/output/BURST20220417181744954.png
#   inflating: /content/hdrnet/train/data/output/BURST20220417181829415.png
#   inflating: /content/hdrnet/train/data/output/BURST20220418132047800.png
#   inflating: /content/hdrnet/train/data/output/BURST20220418132054529.png
#   inflating: /content/hdrnet/train/data/output/BURST20220418141520941.png
#   inflating: /content/hdrnet/train/data/output/BURST20220418162404270.png
#   inflating: /content/hdrnet/train/data/output/BURST20220423112527028.png
#   inflating: /content/hdrnet/train/data/output/BURST20220424104228236.png
#   inflating: /content/hdrnet/train/data/output/BURST20220424104236810.png
#   inflating: /content/hdrnet/train/data/output/BURST20220424104251857.png
#   inflating: /content/hdrnet/train/data/output/BURST20220424104259645.png
#   inflating: /content/hdrnet/train/data/output/BURST20220424135001647.png
#   inflating: /content/hdrnet/train/data/output/BURST20220424151814276.png
#   inflating: /content/hdrnet/train/data/output/BURST20220430184121853.png
#   inflating: /content/hdrnet/train/data/output/BURST20220430184133009.png
#   inflating: /content/hdrnet/train/data/output/BURST20220430184829521.png
#   inflating: /content/hdrnet/train/data/output/BURST20220501115648964.png
#   inflating: /content/hdrnet/train/data/output/BURST20220501140754522.png
#   inflating: /content/hdrnet/train/data/output/BURST20220501151840288.png
#   inflating: /content/hdrnet/train/data/output/BURST20220501173457001.png
#   inflating: /content/hdrnet/train/data/output/BURST20220501174114458.png
#   inflating: /content/hdrnet/train/data/output/BURST20220501174135798.png
#   inflating: /content/hdrnet/train/data/output/BURST20220501174151649.png
#   inflating: /content/hdrnet/train/data/output/BURST20220509192824765.png
#   inflating: /content/hdrnet/train/data/output/BURST20220510011354512.png
#   inflating: /content/hdrnet/train/data/output/BURST20220604121602808.png
#   inflating: /content/hdrnet/train/data/output/BURST20220604122125459.png
#   inflating: /content/hdrnet/train/data/filelist.txt
#   inflating: /content/hdrnet/train/data/output/data.zip

# %%
# !unzip -o /content/gdrive/MyDrive/hdrnet/t1.zip -d /content/hdrnet/train/data/

# %%
#make .so
# %cd /content/hdrnet/hdrnet/ops_oldslice
# %env PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python
#!make clean
# !source /content/env/bin/activate;make

# %cd /content/hdrnet/hdrnet/
#!make clean
#!source /content/env/bin/activate;make

# %cd /content/gdrive/MyDrive/hdrnet/ops
#!make clean
# !source /content/env/bin/activate;make

# %%
#test .so (not ok)
# %cd /content/hdrnet/hdrnet
# !source /content/env/bin/activate;py.test test

# %%
# %cd /content/hdrnet
# !wget https://data.csail.mit.edu/graphics/hdrnet/pretrained_models.zip
# !unzip pretrained_models.zip

# %%
# %cd /content/hdrnet
from google.colab import files
import os
def upload(path):
    uploaded = files.upload()
    with open(path,'wb') as fp:
        fp.write(uploaded[list(uploaded.keys())[0]])
 
def download(path):
    files.download(path)
    
os.makedirs('./in')
os.makedirs('./out')

# %%
# !cp /content/gdrive/MyDrive/hdrnet/train/train_nngd.sh /content/hdrnet/train/

# %%
# !cp /content/gdrive/MyDrive/hdrnet/train/filelist.txt /content/hdrnet/train/data/

# %%
#upload some files to /content/hdrnet/in/ before running...
# !source /content/env/bin/activate;python hdrnet/bin/run.py "/content/hdrnet/pretrained_models/hdrp/"  "/content/hdrnet/in/" "/content/hdrnet/out/" --debug

# %%
# !source /content/env/bin/activate;pip install tensorflow-probability==0.17.0

# %%
#adjust train_nn.sh and put some pics into train/data/input and output, put file names into filelist.txt before training 
# %cd /content/hdrnet/train/
# !chmod +x train_nngd.sh
# !source /content/env/bin/activate;./train_nngd.sh 0

# %%
# %cd /content/hdrnet
# %cd /content/gdrive/MyDrive/hdrnet
#!source /content/env/bin/activate;python hdrnet/bin/run.py "/content/hdrnet/train/out/"  "/content/hdrnet/train/data/filelist.txt" "/content/hdrnet/train/test/" 
# !source /content/env/bin/activate;python hdrnet/bin/run.py "/content/hdrnet/train/out/"  "/content/hdrnet/train/data/input/BURST20210807191513235_hr.png" "/content/hdrnet/train/test/" --debug
#!source /content/env/bin/activate;python hdrnet/bin/run.py "/content/hdrnet/train/out/"  "/content/hdrnet/train/data/input/BURST20210710162353288.png" "/content/hdrnet/train/test/" --debug

#!source /content/env/bin/activate;python hdrnet/bin/run.py "/content/hdrnet/train/out/"  "/content/hdrnet/in/" "/content/hdrnet/out/" --debug
# Out:
# /content/hdrnet
# /content/gdrive/MyDrive/hdrnet
# WARNING:tensorflow:From /content/env/lib/python3.8/site-packages/tensorflow/python/compat/v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# [79418] INFO run.py:62 | Single input /content/hdrnet/train/data/input/BURST20210807191513235_hr.png
# 2023-01-10 23:07:33.859282: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-01-10 23:07:33.872429: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2023-01-10 23:07:33.872490: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (d06c38602514): /proc/driver/nvidia/version does not exist
# [79418] INFO run.py:81 | Loading graph from /content/hdrnet/train/out/on_stop.ckpt.meta
# 2023-01-10 23:07:36.324349: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled
# [79418] INFO run.py:143 | Restoring weights from /content/hdrnet/train/out/on_stop.ckpt
# [79418] INFO run.py:151 | Processing /content/hdrnet/train/data/input/BURST20210807191513235_hr.png
# [79418] WARNING util.py:42 | Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# [79418] WARNING util.py:42 | Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# [79418] WARNING util.py:42 | Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# [79418] WARNING util.py:42 | Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# [79418] WARNING util.py:42 | Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# [79418] WARNING util.py:42 | Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Traceback (most recent call last):
#   File "hdrnet/bin/run.py", line 252, in <module>
#     main(args)
#   File "hdrnet/bin/run.py", line 230, in main
#     print(sess.run(mdl.eps1, feed_dict=feed_dict))
# AttributeError: type object 'HDRNetGaussianPyrNN' has no attribute 'eps1'

# %%
##########################
#some helper stuff for me
##########################

# %%
cp -r /content/hdrnet/train/test /content/gdrive/MyDrive/

# %%
# %cd /content/hdrnet
# !rm -r train/out/*
#!rm train/out2/*
#!zip -r trainout.zip train/out
#!zip -r /content/gdrive/MyDrive/hdrnet/traintest.zip train/test
# Out:
# /content/hdrnet

# %%
# %cd /content/hdrnet/train
# !rm out/model.ckpt*
#!rm train/out2/*
# !zip -r trainout16_32_lev6.zip out
# !cp trainout16_32_lev6.zip /content/gdrive/MyDrive/hdrnet/trainout16_32_lev6.zip

# %%
# %cd /content/hdrnet
# !mv train/out train/out2
# Out:
# /content/hdrnet

# %%
# !unzip /content/gdrive/MyDrive/hdrnet/trainout1616.zip -d /content/hdrnet/train/

# %%
# !source /content/env/bin/activate;tflite_convert --output_file /content/hdrnet/graph.tflite --graph_def_file /content/hdrnet/frozen_graph.pb --input_arrays 'lowres_input' --output_arrays 'output_coefficients'

# %%
import tensorflow as tf
x = tf.range(0, 4, 1, dtype=tf.float64)
xi = tf.concat((tf.range(0, 3, .3, dtype=tf.float64), x[-1:]),  axis=-1)
y = x[:, tf.newaxis]+x[tf.newaxis, :]
interp1(x, xi, y[2])
# Out:
# <tf.Tensor: shape=(11,), dtype=float64, numpy=array([2. , 2.3, 2.6, 2.9, 3.2, 3.5, 3.8, 4.1, 4.4, 4.7, 5. ])>

# %%
def interp1(x, xi, y):
    j   =   tf.argsort(tf.concat((x, xi), axis=-1))
    k   =   tf.range(len(j))
    q   =   tf.scatter_nd(j[:, tf.newaxis], k, k.shape)

    lxi =   len(xi)

    r   =   q[-lxi:]-tf.range(0, lxi)
    r   =   tf.where(xi == x[-1], q[-1:] - lxi, r)

    x2  =   tf.gather(x, r)
    x1  =   tf.gather(x, r-1)
    y2  =   tf.gather(y, r)
    y1  =   tf.gather(y, r-1)

    u   =   (xi-x1)/(x2-x1)
    if not tf.rank(u) == tf.rank(y1):
        u   =   tf.expand_dims(u, axis=-1)

    yi  =   (1.0-u)*y1 + u*y2

    return tf.where(y1 == y2, y1, yi)

# %%
# %cd /content
#!pip3 install virtualenv
#!virtualenv env
# !git clone https://github.com/ZoliN/hdrnet
# %cd /content/hdrnet/hdrnet
# !git checkout tfv2
# Out:
# /content
# Cloning into 'hdrnet'...
# remote: Enumerating objects: 351, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (68/68), done.
# remote: Total 351 (delta 48), reused 82 (delta 33), pack-reused 243
# Receiving objects: 100% (351/351), 9.57 MiB | 35.63 MiB/s, done.
# Resolving deltas: 100% (184/184), done.
# /content/hdrnet/hdrnet
# Branch 'tfv2' set up to track remote branch 'tfv2' from 'origin'.
# Switched to a new branch 'tfv2'

# %%
# !git add .
# !git status
# !git config --global user.email "zltngy@gmail.com"
# !git config --global user.name "ZoliN"
# !git remote set-url origin https://ZoliN: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@github.com/ZoliN/hdrnet.git
# !git commit -m "Add tfp"

# %%
# !git push  origin tfv2
#!git checkout tfv2

# %%
# !cp -r /content/hdrnet/hdrnet/ops_oldslice/ /content/hdrnet/hdrnet/ops_custom

# %%
# %cd /content/gdrive/MyDrive/hdrnet/ops
#!make clean
# !source /content/env/bin/activate;make
# Out:
# /content/gdrive/MyDrive/hdrnet/ops
# /bin/bash: /content/env/bin/activate: No such file or directory
# mkdir -p /content/hdrnet/hdrnet/lib
# c++ -std=c++14 -shared -o /content/hdrnet/hdrnet/lib/hdrnet_ops2.so ./tonecurve.cc ./spline.cpp  -fPIC -I`python -c 'import tensorflow as tf; print(tf.sysconfig.get_include())'` -I. -O2 -D_GLIBCXX_USE_CXX11_ABI=0  `python -c 'import tensorflow as tf; print(" ".join(tf.sysconfig.get_compile_flags()))'` `python -c 'import tensorflow as tf; print(" ".join(tf.sysconfig.get_link_flags()))'` -L/usr/local/cuda/lib64 -lcudart
# <command-line>:0:0: warning: "_GLIBCXX_USE_CXX11_ABI" redefined
# <command-line>:0:0: note: this is the location of the previous definition
# <command-line>:0:0: warning: "_GLIBCXX_USE_CXX11_ABI" redefined
# <command-line>:0:0: note: this is the location of the previous definition

# %%
import os
import tensorflow as tf
from tensorflow.python.framework import ops
#os.kill(os.getpid(), 9)
_hdrnet = tf.load_op_library('/content/hdrnet/hdrnet/lib/hdrnet_ops2.so')
my_test = _hdrnet.my_test

@ops.RegisterGradient('MyTest')
def _my_test_grad(op, grad):
  in_tensor = op.inputs[0]
  params_tensor = op.inputs[1]
  return _hdrnet.my_test_grad(
      in_tensor, params_tensor, grad)

# %%
# %cd /content/gdrive/MyDrive/hdrnet
# !python expfusion.py
# Out:
# /content/gdrive/MyDrive/hdrnet
# (1, 378, 504, 1)
# 2023-01-09 00:45:20.220543: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# tf.Tensor([[1.   7.99]], shape=(1, 2), dtype=float32)
# tf.Tensor([[35.12963]], shape=(1, 1), dtype=float32)
# (1, 47, 63, 1)
# (378, 504, 1)
# WARNING:imageio:Lossy conversion from float32 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.

# %%
v1 = tf.constant([[[[0.20000]]]])
print(my_test(v1, tf.constant([[0.1]])))

x = tf.Variable([[0.1001]])
v1 = tf.Variable([[[[0.2]]]])
with tf.GradientTape(persistent = True) as tape:
  y = my_test(v1, x)
  print(y)
print(tape.gradient(y, x).numpy())
tape.gradient(y, v1).numpy()

# %%
# %cd /content/gdrive/MyDrive/hdrnet/hdrnet/bin
# !source /content/env/bin/activate;python train2.py
#%run train2.py

# %%
# %cd /content/gdrive/MyDrive/hdrnet/hdrnet/bin
#!source /content/env/bin/activate;python run2.py
# %run run2.py

# %%
os.kill(os.getpid(), 9)

# %%
# %cd /content/hdrnet
# !rm -r train/out/*
# Out:
# /content/hdrnet

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Cells
# A notebook is a list of cells. Cells contain either explanatory text or executable code and its output. Click a cell to select it.

# %% [markdown]
# ## Code cells
# Below is a **code cell**. Once the toolbar button indicates CONNECTED, click in the cell to select it and execute the contents in the following ways:
#
# * Click the **Play icon** in the left gutter of the cell;
# * Type **Cmd/Ctrl+Enter** to run the cell in place;
# * Type **Shift+Enter** to run the cell and move focus to the next cell (adding one if none exists); or
# * Type **Alt+Enter** to run the cell and insert a new code cell immediately below it.
#
# There are additional options for running some or all cells in the **Runtime** menu.

# %%
a = 10
a
# Out:
# 10

# %% [markdown]
# ## Text cells
# This is a **text cell**. You can **double-click** to edit this cell. Text cells
# use markdown syntax. To learn more, see our [markdown
# guide](/notebooks/markdown_guide.ipynb).
#
# You can also add math to text cells using [LaTeX](http://www.latex-project.org/)
# to be rendered by [MathJax](https://www.mathjax.org). Just place the statement
# within a pair of **\$** signs. For example `$\sqrt{3x-1}+(1+x)^2$` becomes
# $\sqrt{3x-1}+(1+x)^2.$

# %% [markdown]
# ## Adding and moving cells
# You can add new cells by using the **+ CODE** and **+ TEXT** buttons that show when you hover between cells. These buttons are also in the toolbar above the notebook where they can be used to add a cell below the currently selected cell.
#
# You can move a cell by selecting it and clicking **Cell Up** or **Cell Down** in the top toolbar.
#
# Consecutive cells can be selected by "lasso selection" by dragging from outside one cell and through the group.  Non-adjacent cells can be selected concurrently by clicking one and then holding down Ctrl while clicking another.  Similarly, using Shift instead of Ctrl will select all intermediate cells.

# %% [markdown]
# # Working with python
# Colaboratory is built on top of [Jupyter Notebook](https://jupyter.org/). Below are some examples of convenience functions provided.

# %% [markdown]
# Long running python processes can be interrupted. Run the following cell and select **Runtime -> Interrupt execution** (*hotkey: Cmd/Ctrl-M I*) to stop execution.

# %%
import time
print("Sleeping")
time.sleep(30) # sleep for a while; interrupt me!
print("Done Sleeping")
# Out:
# Sleeping
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-626f81edbca4> in <module>()
#       1 import time
#       2 print "Sleeping"
# ----> 3 time.sleep(30) # sleep for a while; interrupt me!
#       4 print "Done Sleeping"
#
# KeyboardInterrupt:

# %% [markdown]
# ## System aliases
#
# Jupyter includes shortcuts for common operations, such as ls:

# %%
# !ls /bin
# Out:
# arch@      dmesg*          ls*          pwd*        true*
# awk@       dnsdomainname*  lsmod*       readlink*   umount*
# basename@  domainname*     mail*        red@        uname*
# bash*      echo*           mkdir*       rm*         uncompress*
# bunzip2@   ed@             mknod*       rmdir*      usleep*
# busybox*   egrep*          mktemp*      run-parts*  ver*
# bzip2@     false*          more*        sed*        which*
# cat*       fgrep*          mount*       sh@         wrapper_checkpoints/
# chgrp*     gawk@           mountpoint*  sleep*      zcat*
# chmod*     grep*           mv*          sort@       zcmp*
# chown*     gunzip*         nc*          stty*       zdiff*
# cp*        gzexe*          netcat@      su*         zegrep*
# cpio*      gzip*           netstat*     sync*       zfgrep*
# csh@       hostname*       nice@        tailf*      zforce*
# cut@       igawk@          pidof@       tar*        zgrep*
# date*      kill*           ping*        tcsh@       zless*
# dd*        ln*             ping6*       tempfile*   zmore*
# df*        login*          ps*          touch*      znew*

# %% [markdown]
# That `!ls` probably generated a large output. You can select the cell and clear the output by either:
#
# 1. Clicking on the clear output button (x) in the toolbar above the cell; or
# 2. Right clicking the left gutter of the output area and selecting "Clear output" from the context menu.
#
# Execute any other process using `!` with string interpolation from python variables, and note the result can be assigned to a variable:

# %%
message = 'Colaboratory is great!'
foo = !echo -e '$message\n$message'
foo
# Out:
# ['Colaboratory is great!', 'Colaboratory is great!']

# %% [markdown]
# ## Magics
# Colaboratory shares the notion of magics from Jupyter. There are shorthand annotations that change how a cell's text is executed. To learn more, see [Jupyter's magics page](http://nbviewer.jupyter.org/github/ipython/ipython/blob/1.x/examples/notebooks/Cell%20Magics.ipynb).

# %%
# %%html
# <marquee style='width: 30%; color: blue;'><b>Whee!</b></marquee>
# Out:
# <marquee style='width: 30%; color: blue;'><b>Whee!</b></marquee>

# %%
# %%html
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 450 400" width="200" height="200">
#   <rect x="80" y="60" width="250" height="250" rx="20" style="fill:red; stroke:black; fill-opacity:0.7" />
#   <rect x="180" y="110" width="250" height="250" rx="40" style="fill:blue; stroke:black; fill-opacity:0.5;" />
# </svg>
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 450 400" width="200" height="200">
#   <rect x="80" y="60" width="250" height="250" rx="20" style="fill:red; stroke:black; fill-opacity:0.7" />
#   <rect x="180" y="110" width="250" height="250" rx="40" style="fill:blue; stroke:black; fill-opacity:0.5;" />
# </svg>

# %% [markdown]
# ## Automatic completions and exploring code
#
# Colab provides automatic completions to explore attributes of Python objects, as well as to quickly view documentation strings. As an example, first run the following cell to import the  [`numpy`](http://www.numpy.org) module.

# %%
import numpy as np

# %% [markdown]
# If you now insert your cursor after `np` and press **Period**(`.`), you will see the list of available completions within the `np` module. Completions can be opened again by using **Ctrl+Space**.

# %%
np

# %% [markdown]
# If you type an open parenthesis after any function or class in the module, you will see a pop-up of its documentation string:

# %%
np.ndarray

# %% [markdown]
# The documentation can be opened again using **Ctrl+Shift+Space** or you can view the documentation for method by mouse hovering over the method name.
#
# When hovering over the method name the `Open in tab` link will open the documentation in a persistent pane. The `View source` link will navigate to the source code for the method.

# %% [markdown]
# ## Exception Formatting

# %% [markdown]
# Exceptions are formatted nicely in Colab outputs:

# %%
x = 1
y = 4
z = y/(1-x)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-14-dc39888fd1d2> in <module>()
#       1 x = 1
#       2 y = 4
# ----> 3 z = y/(1-x)
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# ## Rich, interactive outputs
# Until now all of the generated outputs have been text, but they can be more interesting, like the chart below.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Fills and Alpha Example")
plt.show()

# %% [markdown]
# # Integration with Drive
#
# Colaboratory is integrated with Google Drive. It allows you to share, comment, and collaborate on the same document with multiple people:
#
# * The **SHARE** button (top-right of the toolbar) allows you to share the notebook and control permissions set on it.
#
# * **File->Make a Copy** creates a copy of the notebook in Drive.
#
# * **File->Save** saves the File to Drive. **File->Save and checkpoint** pins the version so it doesn't get deleted from the revision history.
#
# * **File->Revision history** shows the notebook's revision history.

# %% [markdown]
# ## Commenting on a cell
# You can comment on a Colaboratory notebook like you would on a Google Document. Comments are attached to cells, and are displayed next to the cell they refer to. If you have **comment-only** permissions, you will see a comment button on the top right of the cell when you hover over it.
#
# If you have edit or comment permissions you can comment on a cell in one of three ways:
#
# 1. Select a cell and click the comment button in the toolbar above the top-right corner of the cell.
# 1. Right click a text cell and select **Add a comment** from the context menu.
# 3. Use the shortcut **Ctrl+Shift+M** to add a comment to the currently selected cell.
#
# You can resolve and reply to comments, and you can target comments to specific collaborators by typing *+[email address]* (e.g., `+user@domain.com`). Addressed collaborators will be emailed.
#
# The Comment button in the top-right corner of the page shows all comments attached to the notebook.
